# %% [markdown]
# # Physics Practice - (URM) - Lvl 3
# #### Notebook 4 - Uniform rectilinear motion
# <b>Programmer:</b> Carlos Prado. - 17/12/2018
# <b>Objective:</b> To review URM,learn the Latex language and implement the code in Python

# %% [markdown]
# #### Exercise 1
# A train and a car depart from the same point simultaneously with speeds of 6 m/s and 4 m/s in opposite directions to cities A and B. Once they reach their destination, they depart back. At what distance from A do they meet again?
#
# <b>Res:</b>:
# ###### Train  ; $t = \frac {e}{v}$
# - $vt = 6 \frac {m}{\sec}$
# - $et1 = 120 m $
# - $et2 = ? $
# - $tt1 = ? $
# - $tt2 = ? $
#
#
# - $tt_{1} = \frac {et_{1}}{vt} = \frac {120 m}{6\frac{m}{\sec}}= 20\sec$
#
# - $tt_{2} = \frac {et_{2}}{vt} = \frac {et_{2}}{6\frac{m}{\sec}}$
#
# - $et_{2} = 6tt_{2} = 6(36) = 216 m $
#
# ###### Car   ; $t = \frac {e}{v}$
# - $vc = 4 \frac {m}{\sec}$
# - $ec1 = 160 m $
# - $ec2 = ? $
# - $tc1 = ? $
# - $tc2 = ? $
#
#
# - $tc_{1} = \frac {ec_{1}}{vc} = \frac {160 m}{4\frac{m}{\sec}} = 40\sec$
#
# - $tc_{2} = \frac {ec_{2}}{vc} = \frac {ec_{2}}{4\frac{m}{\sec}}$
#
# - $ec_{2} = 4tc_{2} = 4(16)= 64m$
#
# ###### --*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# ###### train lap time
#
# $tt_{1} + tt_{2} = tc_{1} + tc_{2}$
#
# $20 + tt_{2} = 40 + tc_{2}$
#
# $tt_{2} = 20 + tc_{2} = 20 + 16 = 36 \sec$
#
#
# ##### car lap time
# $et_{2} + ec_{2} = 120 + 160 $
#
# $6tt_{2} + 4tc_{2}= 280$
#
# $6(20 + tc_{2}) + 4tc_{2} = 280$
#
# $120 + 6tc_{2} + 4tc_{2} = 280$
#
# $10tc_{2}  = 280 - 120$
#
# $10tc_{2} = 160$
#
# $tc_{2} = \frac {160}{10} = 16\sec$

# %%
from vpython import *

# Train
vt = 6; tt1 = 20; tt2 = 36; et1 = 120; et2 = 216
# Car
vc = 4; tc1 = 40; tc2 = 16; ec1 = 160; ec2 = 64
#Escene
canvas(title='Exercise 1',width=600, height=300,center=vector(0,0,0),
background=color.black)

#create objects
x_012 = sphere(pos=vector(-60,0,0), radius=0.5, color = color.cyan)
L012 = label(pos=x_012.pos,text='ET1 = 120m', xoffset=0,yoffset=50, space=20,
    height=8, border=2,font='sans')
x_011 = sphere(pos=vector(-55,0,0), radius=0.5, color = color.cyan)
L011 = label(pos=x_011.pos,text='110m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_010 = sphere(pos=vector(-50,0,0), radius=0.5, color = color.cyan)
L010 = label(pos=x_010.pos,text='100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_009 = sphere(pos=vector(-45,0,0), radius=0.5, color = color.cyan)
L009 = label(pos=x_009.pos,text='90m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_008 = sphere(pos=vector(-40,0,0), radius=0.5, color = color.cyan)
L008 = label(pos=x_008.pos,text='80m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_007 = sphere(pos=vector(-35,0,0), radius=0.5, color = color.cyan)
L007 = label(pos=x_007.pos,text='70m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_006 = sphere(pos=vector(-30,0,0), radius=0.5, color = color.cyan)
L006 = label(pos=x_006.pos,text='60m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_005 = sphere(pos=vector(-25,0,0), radius=0.5, color = color.cyan)
L005 = label(pos=x_005.pos,text='50m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_004 = sphere(pos=vector(-20,0,0), radius=0.5, color = color.cyan)
L004 = label(pos=x_004.pos,text='40m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_003 = sphere(pos=vector(-15,0,0), radius=0.5, color = color.cyan)
L003 = label(pos=x_003.pos,text='30m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_002 = sphere(pos=vector(-10,0,0), radius=0.5, color = color.cyan)
L002 = label(pos=x_002.pos,text='20m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_001 = sphere(pos=vector(-5,0,0), radius=0.5, color = color.cyan)
L001 = label(pos=x_001.pos,text='10m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_000 = sphere(pos=vector(0,0,0), radius=0.5, color = color.green) 
L000 = label(pos=x_000.pos,text='Start', xoffset=0,yoffset=50, space=20,
    height=10, border=4,
    font='sans')
x_01 = sphere(pos=vector(5,0,0), radius=0.5, color = color.yellow)
L01 = label(pos=x_01.pos,text='10m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_02 = sphere(pos=vector(10,0,0), radius=0.5, color = color.yellow)
L02 = label(pos=x_02.pos,text='20m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_03 = sphere(pos=vector(15,0,0), radius=0.5, color = color.yellow)
L03 = label(pos=x_03.pos,text='30m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_04 = sphere(pos=vector(20,0,0), radius=0.5, color = color.yellow)
L04 = label(pos=x_04.pos,text='40m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,font='sans')
x_05 = sphere(pos=vector(25,0,0), radius=0.5, color = color.yellow)
L05 = label(pos=x_05.pos,text='50m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')
x_06 = sphere(pos=vector(30,0,0), radius=0.5, color = color.yellow)
L06 = label(pos=x_06.pos,text='60m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')
x_07 = sphere(pos=vector(35,0,0), radius=0.5, color = color.yellow)
L07 = label(pos=x_07.pos,text='70m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans') 
x_08 = sphere(pos=vector(40,0,0), radius=0.5, color = color.yellow)
L08 = label(pos=x_08.pos,text='80m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_09 = sphere(pos=vector(45,0,0), radius=0.5, color = color.yellow)
L09 = label(pos=x_09.pos,text='90m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_10 = sphere(pos=vector(50,0,0), radius=0.5, color = color.yellow)
L10 = label(pos=x_10.pos,text='100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_11 = sphere(pos=vector(55,0,0), radius=0.5, color = color.yellow)
L11 = label(pos=x_11.pos,text='110m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_12 = sphere(pos=vector(60,0,0), radius=0.5, color = color.yellow)
L12 = label(pos=x_12.pos,text='120m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_13 = sphere(pos=vector(65,0,0), radius=0.5, color = color.yellow)
L13 = label(pos=x_13.pos,text='130m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_14 = sphere(pos=vector(70,0,0), radius=0.5, color = color.yellow)
L14 = label(pos=x_14.pos,text='140m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_15 = sphere(pos=vector(75,0,0), radius=0.5, color = color.yellow)
L15 = label(pos=x_15.pos,text='150m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_16 = sphere(pos=vector(80,0,0), radius=0.5, color = color.yellow)
L16 = label(pos=x_16.pos,text='EC1= 160m', xoffset=0,yoffset=50, space=20,
    height=8, border=2,              
    font='sans')     

train = box(pos=vector(0,0,0), radius=30, 
            color = color.green,make_trail = True,
          trail_type="points")
Lab100 = label(pos=train.pos,text='Train', xoffset=0,yoffset=50, space=20,
    height=10, border=4,
    font='sans')
car = box(pos=vector(0,0,0), radius=30, 
          color = color.yellow,make_trail = True,
          trail_type="points")
Lab12 = label(pos=car.pos,text='Car', xoffset=0,yoffset=50, space=20,
    height=10, border=4,
    font='sans')

# -- Creamos un vector de posición --
trainv= vector(-0.6,0,0)
carv= vector(0.4,0,0)

k = 15
    
for i in range(141):
    rate(k)
    if i == 50 :
        trainv = vector(0.6,0,0)
        continue
    if i == 100 :    
        carv = vector(-0.4,0,0)
        continue
    car.pos = car.pos + carv
    Lab12.pos = Lab12.pos + carv
    train.pos = train.pos + trainv
    Lab100.pos = Lab100.pos + trainv
    
    car.pos += carv
    Lab12.pos+=carv
    train.pos += trainv
    Lab100.pos+=trainv
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# #### Exercise 2
# A dog and its master are separated 800 m, depart at the same time and at a constant speed of 3m/s and 5 m/s and in opposite directions, they cross each other and go on long. How long since they left, will it be separated 1200m ?
#
# <b>Res:</b>:
# ###### Master
# - $vm = 5 \frac {m}{\sec}$
# - $em_{1}= 800 m $
# - $em_{2} = 1200 m $
# - $tm_{1} = ? $
# - $tm_{2}= ? $
#
# ##### Calculation of the time in which they are crossed
#
# - $e = v \cdot t$
# - $em_{1} = vm \cdot tm_{1}$
# - $em_{1} = 5tm_{1}$
# - $em_{2}= em_{1} = 5tm_{1}$
#
#
# - $800 = em_{1} + ed_{1}$
# - $800 = 5tm_{1}+ 3tm_{1}$
# - $800 = 8tm_{1}$
# - $tm_{1} = \frac {800}{8}$
# - $tm_{1} = 100\sec$
#
# ##### Calculation of the time in which they were separated
#
# - $1200 = em_{2} + ed_{2}$
# - $1200 = 5tm_{2} + 3tm_{2}$
# - $1200 = 8tm_{2}$
# - $tm_{2} =\frac{1200}{8}$
# - $tm_{2} =150\sec$
#
#
# ###### Dog   ; $t = \frac {e}{v}$
# - $vd = 3 \frac {m}{\sec}$
# - $ed_{1} = 800 m $
# - $ed_{2} = 1200 $
# - $td_{1} = ? $
# - $td_{2} = ? $
#
# - $td_{1} = tm_{1} = 100\sec$
# - $td_{2} = tm_{2} = 150\sec$
#
# - $e = v \cdot t$
# - $ed_{1} = vd \cdot td_{1}$
# - $ed_{1} = 3tm_{1}$
# - $ed_{2}= ed_{1} = 3tm_{1}$

# %%
from vpython import *

# Master escala 1/10
vm = -0.5; tm1 = 100; tm2 = 150; em1 = 800; em2 = 1200
# Dog
vd = 0.3; td1 = 100; td2 = 150; ed1 = 800; ed2 = 1200
#Escene
canvas(title='Exercise 2',width=600, height=300,center=vector(0,0,0),background=color.black)

#create objects
"""x_012 = sphere(pos=vector(-60,0,0), radius=0.5, color = color.white)
L012 = label(pos=x_012.pos,text='1200m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,font='sans')
x_011 = sphere(pos=vector(-55,0,0), radius=0.5, color = color.white)
L011 = label(pos=x_011.pos,text='1100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_010 = sphere(pos=vector(-50,0,0), radius=0.5, color = color.white)
L010 = label(pos=x_010.pos,text='1000m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')"""
x_009 = sphere(pos=vector(-45,0,0), radius=0.5, color = color.white)
L009 = label(pos=x_009.pos,text='900m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_008 = sphere(pos=vector(-40,0,0), radius=0.5, color = color.white)
L008 = label(pos=x_008.pos,text='800m',xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_007 = sphere(pos=vector(-35,0,0), radius=0.5, color = color.white)
L007 = label(pos=x_007.pos,text='700m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_006 = sphere(pos=vector(-30,0,0), radius=0.5, color = color.white)
L006 = label(pos=x_006.pos,text='600m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_005 = sphere(pos=vector(-25,0,0), radius=0.5, color = color.white)
L005 = label(pos=x_005.pos,text='500m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_004 = sphere(pos=vector(-20,0,0), radius=0.5, color = color.cyan)
L004 = label(pos=x_004.pos,text='400m',color=color.yellow,xoffset=0,
             yoffset=-50, space=20,
    height=10, border=4,
    font='sans')
x_003 = sphere(pos=vector(-15,0,0), radius=0.5, color = color.white)
L003 = label(pos=x_003.pos,text='300m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_002 = sphere(pos=vector(-10,0,0), radius=0.5, color = color.white)
L002 = label(pos=x_002.pos,text='200m', xoffset=0,
             yoffset=-50, space=20,height=8, border=2,font='sans')
x_001 = sphere(pos=vector(-5,0,0), radius=0.5, color = color.red)
L001 = label(pos=x_001.pos,color=color.yellow,text='100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_000 = sphere(pos=vector(0,0,0), radius=0.5, color = color.white) 
L000 = label(pos=x_000.pos,text='0m', xoffset=0,yoffset=-50, space=20,
    height=10, border=4,
    font='sans')
x_01 = sphere(pos=vector(5,0,0), radius=0.5, color = color.white)
L01 = label(pos=x_01.pos,text='100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_02 = sphere(pos=vector(10,0,0), radius=0.5, color = color.white)
L02 = label(pos=x_02.pos,text='200m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_03 = sphere(pos=vector(15,0,0), radius=0.5, color = color.white)
L03 = label(pos=x_03.pos,text='300m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,
    font='sans')
x_04 = sphere(pos=vector(20,0,0), radius=0.5, color = color.green)
L04 = label(pos=x_04.pos,text='400m',color=color.yellow,xoffset=0,
            yoffset=-50, space=20,
    height=10, border=4,font='sans')
x_05 = sphere(pos=vector(25,0,0), radius=0.5, color = color.white)
L05 = label(pos=x_05.pos,text='500m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')
x_06 = sphere(pos=vector(30,0,0), radius=0.5, color = color.white)
L06 = label(pos=x_06.pos,text='600m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')
x_07 = sphere(pos=vector(35,0,0), radius=0.5, color = color.white)
L07 = label(pos=x_07.pos,text='700m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans') 
x_08 = sphere(pos=vector(40,0,0), radius=0.5, color = color.white)
L08 = label(pos=x_08.pos,text='800m', 
            xoffset=0,yoffset=-50, space=20,height=8, border=2,
            font='sans')     
x_09 = sphere(pos=vector(45,0,0), radius=0.5, color = color.white)
L09 = label(pos=x_09.pos,text='900m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
""" x_10 = sphere(pos=vector(50,0,0), radius=0.5, color = color.white)
L10 = label(pos=x_10.pos,text='1000m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_11 = sphere(pos=vector(55,0,0), radius=0.5, color = color.white)
L11 = label(pos=x_11.pos,text='1100m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     
x_12 = sphere(pos=vector(60,0,0), radius=0.5, color = color.white)
L12 = label(pos=x_12.pos,text='1200m', xoffset=0,yoffset=-50, space=20,
    height=8, border=2,              
    font='sans')     """


master = box(pos=vector(20,0,0), radius=30, color = color.green,make_trail = True,
          trail_type="points")
Lab100 = label(pos=master.pos,text='Master',color=color.green, xoffset=0,yoffset=50, space=20,
    height=10, border=4,
    font='sans')
dog = box(pos=vector(-20,0,0), radius=30, color = color.cyan,make_trail = True,
          trail_type="points")
Lab12 = label(pos=dog.pos,text='Dog',color=color.cyan, xoffset=0,yoffset=50, space=20,
    height=10, border=4,
    font='sans')

# -- Creamos un vector de posición --
masterv= vector(vm,0,0)
dogv= vector(vd,0,0)

k = 10
    
for i in range(63):
    rate(k)
    
    dog.pos = dog.pos + dogv
    Lab12.pos = Lab12.pos + dogv
    master.pos = master.pos + masterv
    Lab100.pos = Lab100.pos + masterv
    
    dog.pos += dogv
    Lab12.pos+=dogv
    master.pos += masterv
    Lab100.pos+=masterv
# Out:
# <div id="glowscript" class="glowscript"></div>
