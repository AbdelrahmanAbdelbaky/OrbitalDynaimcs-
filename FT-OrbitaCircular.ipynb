# %% [markdown]
# <b>20/11/2018 - FT - Orbita Circular - 02 </b>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
import scipy as sc

# %%
# CREANDO EL DATASET
fig, ax = plt.subplots()
ax.add_patch(plt.Circle((0.6, 0), 0.09, color='y', alpha=0.39))
ax.add_patch(plt.Circle((0, 0), 0.2, color='b', alpha=0.3))
ax.add_patch(plt.Circle((0, 0), 0.6, color='black', alpha=0.2))
ax.set_aspect('equal', adjustable='datalim')
ax.plot()   #Causes an autoscale update.
plt.grid(color='black')


# here must be something like circle.plot() or not?
plt.show()

# %%
# CREAR EL DATASET



X, Y = make_circles(n_samples=n, factor=0.3, noise=0.00)

Y = Y[:, np.newaxis]

plt.scatter(X[Y[:, 0] == 0, 0], X[Y[:, 0] == 0, 1], c="skyblue")
plt.scatter(X[Y[:, 0] == 1, 0], X[Y[:, 0] == 1, 1], c="salmon")
plt.axis("equal")
plt.grid()
plt.show()

# %%
# c - - Simulador Visual.
from __future__ import division
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi

angles = pi*np.random.randint(0,100,100)/10
ax = plt.subplot(111, polar=True)
ax.scatter(angles, np.ones(100)*1)

# suppress the radial labels
plt.setp(ax.get_yticklabels(), visible=False)

# set the circumference labels
ax.set_xticks(np.linspace(0, 2*pi, 24, endpoint=False))
#ax.set_xticklabels(range(24))

# make the labels go clockwise
#ax.set_theta_direction(-1)

# place 0 at the top
#ax.set_theta_offset(1)    

# plt.grid('off')
# Propiedades del grid
ax.grid(which='major', axis='x', linewidth=0.30, linestyle='-', color='b')
#ax.grid(which='minor', axis='x', linewidth=1, linestyle='-', color='r')
ax.grid(which='major', axis='y', linewidth=0.25, linestyle='-', color='black')
#ax.grid(which='minor', axis='y', linewidth=3, linestyle='-', color='r')
# put the points on the circumference
plt.ylim(0,1)

plt.show()
